# %% [markdown]
# # Data Exploration - Revenue Intelligence System
#
# This notebook explores the CRM dataset and documents data quality issues.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sqlalchemy import create_engine
from datetime import datetime, timedelta

# Styling
sns.set_style('darkgrid')
plt.rcParams['figure.figsize'] = (12, 6)

print("Libraries loaded successfully!")

# %% [markdown]
# ## 1. Load Data
#
# Load data from the database or CSV file.

# %%
# Connect to database
DATABASE_URL = "postgresql://app:dev_password@localhost:5432/revenue_intel"

# Uncomment when database is ready
# engine = create_engine(DATABASE_URL)
# deals_df = pd.read_sql("SELECT * FROM open_deals_with_scores", engine)

print("Database connection will be tested once schema is initialized.")
print("For now, we'll work with sample/demo data.")
